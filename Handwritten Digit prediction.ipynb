# %% [markdown]
# # Handwritten digit recognition: A neural network approach
#
# Handwritten digit recognition is a good first-lesson on image recognition for beginners.
# <br />
# The MNIST dataset consists 60000 training examples and 10000 test examples, of digits 0-9
# <br />
# In this project we will:
#
# - Implement a 2-layer neural network.
# - Compute the forward pass and backward pass with svm loss.
# - Use the normlizaiton to help network converge.
# - Use a stochastic gradient descent to optimize the loss function.
# - Try a new type of neural network: Resnet, and apply the methodology to a three layer neural network.

# %%
from data_utils import loadMNIST

from __future__ import print_function
from two_layer_net import *
from three_layer_net import *

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load the data
# Load the MNIST data to train a neural network. The data is located at `'dataset/'` directory, you should download the 4 ubyte files from [Yann Lecun's website](http://yann.lecun.com/exdb/mnist/) and unextract it in the right directory before loading. Dataset directory may vary when you change the location of you project folder, or use a different operating system. Make sure to modify `data_utils.py` when you change the dataset location.

# %%
X_train, y_train = loadMNIST(dataset="training", num_image=60000)
X_test, y_test = loadMNIST(dataset="test", num_image=10000)

print("Loaded training images of shape:", X_train.shape)
print("Loaded training labels of shape:", y_train.shape)
print("Loaded test images of shape", X_test.shape)
print("Loaded test labels of shape", y_test.shape)
# Out:
# Loaded training images of shape: (60000, 28, 28)
# Loaded training labels of shape: (60000,)
# Loaded test images of shape (10000, 28, 28)
# Loaded test labels of shape (10000,)

# %% [markdown]
# # Show some random images
# Show some random images to get a gut feeling of how the data looks like.
# Make sure `row * col` is less than the size of training set example number.
# To adjust the size of plot size, just modify: `plt.rcParams['figure.figsize']` on the first code block.

# %%
row, col = 5, 10
idx = np.random.choice(X_train.shape[0], row*col, replace=False)
for i in range(row):
    for j in range(col):
        plt_idx = idx[i*col+j]
        plt.subplot(row, col, i*col+j+1)
        plt.title(y_train[plt_idx])
        plt.imshow(X_train[plt_idx,:,:])
        plt.axis('off')

plt.show()

# %% [markdown]
# # Preprocess the data
# ## Preprocess Part.1
# In this part, we preprocess the data by:
#
# - Split training set data to train and validation.
# - Normalize the data

# %%
X_train, y_train = loadMNIST(dataset="training", num_image=60000)
X_test, y_test = loadMNIST(dataset="test", num_image=10000)

# Split the data into train, val, and test sets. 
num_training = 50000
num_validation = 10000
num_test = 10000

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test)
X_test = X_test[mask]
y_test = y_test[mask]


# Normalize the data: subtract the mean image
mean_image = np.mean(X_train, axis=0)
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image


print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (50000, 28, 28)
# Train labels shape:  (50000,)
# Validation data shape:  (10000, 28, 28)
# Validation labels shape:  (10000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)

# %% [markdown]
# ## Preprocess Part.2
# Reshape the 3 dimension data to a `[N * (row * col)]` 2 dimension matrix.
# `N` is the number of examples, `(row, col)` is the shape of an example image.

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
# Out:
# Training data shape:  (50000, 784)
# Validation data shape:  (10000, 784)
# Test data shape:  (10000, 784)

# %% [markdown]
# # Overfit Small Dataset
# Training with a small dataset, i.e. a training set with 1000 example images, we should see an overfitting model.

# %%
# Preprocessing: reshape the image data into rows
X_train_small = X_train[:1000, :]
y_train_small = y_train[:1000]
# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train_small.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
# Out:
# Training data shape:  (1000, 784)
# Validation data shape:  (10000, 784)
# Test data shape:  (10000, 784)

# %%
input_size = 28 * 28
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train_small, y_train_small, X_val, y_val,
            num_iters=1000, batch_size=50,
            learning_rate=1e-3, learning_rate_decay=0.99,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
train_acc = (net.predict(X_train_small) == y_train_small).mean()
print('Validation accuracy: ', val_acc)
print('Train accuracy: ', train_acc)
# Out:
# iteration 0 / 1000: loss 9.000163 val_acc 0.178800
# iteration 100 / 1000: loss 0.112513 val_acc 0.872400
# iteration 200 / 1000: loss 0.060676 val_acc 0.880800
# iteration 300 / 1000: loss 0.073504 val_acc 0.880800
# iteration 400 / 1000: loss 0.049537 val_acc 0.883600
# iteration 500 / 1000: loss 0.040760 val_acc 0.885800
# iteration 600 / 1000: loss 0.039260 val_acc 0.886200
# iteration 700 / 1000: loss 0.038064 val_acc 0.886800
# iteration 800 / 1000: loss 0.039735 val_acc 0.886500
# iteration 900 / 1000: loss 0.036329 val_acc 0.884600
# Validation accuracy:  0.8874
# Train accuracy:  1.0

# %%
# Plot the loss function and train / validation accuracies
plt.rcParams['figure.figsize'] = (20.0, 10.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'none'

plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], 'r', label='train')
plt.plot(stats['val_acc_history'], 'b', label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Training
# Train a two layer neural network, update gradients with mini-batch data, optimize the loss with SGD.

# %%
input_size = 28 * 28
hidden_size = 200
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=10000, batch_size=200,
            learning_rate=1e-3, learning_rate_decay=0.99,
            reg=0.2, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
train_acc = (net.predict(X_train) == y_train).mean()
print('Validation accuracy: ', val_acc)
print('Train accuracy: ', train_acc)
# Out:
# iteration 0 / 10000: loss 9.000077 val_acc 0.484000
# iteration 100 / 10000: loss 0.341954 val_acc 0.932000
# iteration 200 / 10000: loss 0.249994 val_acc 0.943000
# iteration 300 / 10000: loss 0.222118 val_acc 0.952600
# iteration 400 / 10000: loss 0.198258 val_acc 0.958900
# iteration 500 / 10000: loss 0.183646 val_acc 0.962100
# iteration 600 / 10000: loss 0.218462 val_acc 0.965900
# iteration 700 / 10000: loss 0.127938 val_acc 0.967300
# iteration 800 / 10000: loss 0.165340 val_acc 0.969000
# iteration 900 / 10000: loss 0.099367 val_acc 0.969300
# iteration 1000 / 10000: loss 0.083572 val_acc 0.970100
# iteration 1100 / 10000: loss 0.101419 val_acc 0.973100
# iteration 1200 / 10000: loss 0.113964 val_acc 0.971600
# iteration 1300 / 10000: loss 0.117867 val_acc 0.975300
# iteration 1400 / 10000: loss 0.173251 val_acc 0.973500
# iteration 1500 / 10000: loss 0.116824 val_acc 0.975100
# iteration 1600 / 10000: loss 0.111470 val_acc 0.975400
# iteration 1700 / 10000: loss 0.125082 val_acc 0.975600
# iteration 1800 / 10000: loss 0.093538 val_acc 0.976000
# iteration 1900 / 10000: loss 0.105815 val_acc 0.977400
# iteration 2000 / 10000: loss 0.074719 val_acc 0.976800
# iteration 2100 / 10000: loss 0.099308 val_acc 0.977600
# iteration 2200 / 10000: loss 0.099154 val_acc 0.979200
# iteration 2300 / 10000: loss 0.076744 val_acc 0.976800
# iteration 2400 / 10000: loss 0.118680 val_acc 0.978100
# iteration 2500 / 10000: loss 0.067034 val_acc 0.978200
# iteration 2600 / 10000: loss 0.066520 val_acc 0.978400
# iteration 2700 / 10000: loss 0.065812 val_acc 0.978800
# iteration 2800 / 10000: loss 0.077619 val_acc 0.977800
# iteration 2900 / 10000: loss 0.079757 val_acc 0.978000
# iteration 3000 / 10000: loss 0.114866 val_acc 0.978700
# iteration 3100 / 10000: loss 0.075081 val_acc 0.978700
# iteration 3200 / 10000: loss 0.072179 val_acc 0.977400
# iteration 3300 / 10000: loss 0.078651 val_acc 0.978400
# iteration 3400 / 10000: loss 0.078789 val_acc 0.979000
# iteration 3500 / 10000: loss 0.090237 val_acc 0.979100
# iteration 3600 / 10000: loss 0.073586 val_acc 0.981500
# iteration 3700 / 10000: loss 0.080772 val_acc 0.979400
# iteration 3800 / 10000: loss 0.088778 val_acc 0.980400
# iteration 3900 / 10000: loss 0.074397 val_acc 0.979400
# iteration 4000 / 10000: loss 0.058732 val_acc 0.979900
# iteration 4100 / 10000: loss 0.077202 val_acc 0.979000
# iteration 4200 / 10000: loss 0.074691 val_acc 0.980400
# iteration 4300 / 10000: loss 0.049820 val_acc 0.979900
# iteration 4400 / 10000: loss 0.059817 val_acc 0.980300
# iteration 4500 / 10000: loss 0.077076 val_acc 0.980100
# iteration 4600 / 10000: loss 0.066258 val_acc 0.980400
# iteration 4700 / 10000: loss 0.074137 val_acc 0.981100
# iteration 4800 / 10000: loss 0.068607 val_acc 0.982200
# iteration 4900 / 10000: loss 0.057535 val_acc 0.980500
# iteration 5000 / 10000: loss 0.070049 val_acc 0.980900
# iteration 5100 / 10000: loss 0.059293 val_acc 0.980600
# iteration 5200 / 10000: loss 0.090744 val_acc 0.980600
# iteration 5300 / 10000: loss 0.070716 val_acc 0.980600
# iteration 5400 / 10000: loss 0.065958 val_acc 0.981900
# iteration 5500 / 10000: loss 0.056538 val_acc 0.980900
# iteration 5600 / 10000: loss 0.065454 val_acc 0.980400
# iteration 5700 / 10000: loss 0.058067 val_acc 0.980600
# iteration 5800 / 10000: loss 0.082760 val_acc 0.981100
# iteration 5900 / 10000: loss 0.069921 val_acc 0.981200
# iteration 6000 / 10000: loss 0.077533 val_acc 0.980600
# iteration 6100 / 10000: loss 0.064608 val_acc 0.981400
# iteration 6200 / 10000: loss 0.059364 val_acc 0.981200
# iteration 6300 / 10000: loss 0.068857 val_acc 0.980200
# iteration 6400 / 10000: loss 0.078736 val_acc 0.981900
# iteration 6500 / 10000: loss 0.071568 val_acc 0.981000
# iteration 6600 / 10000: loss 0.063480 val_acc 0.981000
# iteration 6700 / 10000: loss 0.075820 val_acc 0.981600
# iteration 6800 / 10000: loss 0.075577 val_acc 0.981600
# iteration 6900 / 10000: loss 0.059022 val_acc 0.981000
# iteration 7000 / 10000: loss 0.073266 val_acc 0.981000
# iteration 7100 / 10000: loss 0.078061 val_acc 0.981800
# iteration 7200 / 10000: loss 0.057141 val_acc 0.981200
# iteration 7300 / 10000: loss 0.058668 val_acc 0.980700
# iteration 7400 / 10000: loss 0.060121 val_acc 0.981300
# iteration 7500 / 10000: loss 0.065360 val_acc 0.980800
# iteration 7600 / 10000: loss 0.067743 val_acc 0.982000
# iteration 7700 / 10000: loss 0.067388 val_acc 0.981400
# iteration 7800 / 10000: loss 0.074024 val_acc 0.981100
# iteration 7900 / 10000: loss 0.080889 val_acc 0.981100
# iteration 8000 / 10000: loss 0.074831 val_acc 0.981200
# iteration 8100 / 10000: loss 0.081381 val_acc 0.981100
# iteration 8200 / 10000: loss 0.059840 val_acc 0.981900
# iteration 8300 / 10000: loss 0.060255 val_acc 0.980300
# iteration 8400 / 10000: loss 0.074970 val_acc 0.980400
# iteration 8500 / 10000: loss 0.071532 val_acc 0.982000
# iteration 8600 / 10000: loss 0.071561 val_acc 0.980500
# iteration 8700 / 10000: loss 0.053562 val_acc 0.981800
# iteration 8800 / 10000: loss 0.056864 val_acc 0.981100
# iteration 8900 / 10000: loss 0.053408 val_acc 0.981900
# iteration 9000 / 10000: loss 0.070366 val_acc 0.981600
# iteration 9100 / 10000: loss 0.059128 val_acc 0.981400
# iteration 9200 / 10000: loss 0.058160 val_acc 0.981800
# iteration 9300 / 10000: loss 0.076919 val_acc 0.981100
# iteration 9400 / 10000: loss 0.062462 val_acc 0.980200
# iteration 9500 / 10000: loss 0.058924 val_acc 0.981300
# iteration 9600 / 10000: loss 0.070648 val_acc 0.981300
# iteration 9700 / 10000: loss 0.060501 val_acc 0.981500
# iteration 9800 / 10000: loss 0.058306 val_acc 0.981600
# iteration 9900 / 10000: loss 0.053567 val_acc 0.981200
# Validation accuracy:  0.9804
# Train accuracy:  0.99786

# %% [markdown]
# # Debug the training
# The loss history indicates whether loss is converging.
# Overfitting or underfitting can be observed from classification accuracy history.
# If there is a big gap between training accuracy and validation accuracy curves, the model is highly possible overfitting. Else if the training accuracy is low, and validation accuracy alike, the model might be underfitting.
# To avoid such occasions, fine tune the parameters with your observation on the plots.

# %%
# Plot the loss function and train / validation accuracies
plt.rcParams['figure.figsize'] = (20.0, 10.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'none'

plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Performance of the model
# Now it's time to finally evaluate our model, with test set data.

# %%
test_acc = (net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.9804

# %% [markdown]
# # Show some random image and predict using our model

# %%
plt.rcParams['figure.figsize'] = (8.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'

row, col = 5, 8
y_test_pred = net.predict(X_test)
X_test_image = X_test.reshape(-1, 28, 28)
idx = np.random.choice(X_test.shape[0], row*col, replace=False)
for i in range(row):
    for j in range(col):
        plt_idx = idx[i*col+j]
        plt.subplot(row, col, i*col+j+1)
        plt.title('pred: ' + str(y_test_pred[plt_idx]))
        plt.imshow(X_test_image[plt_idx,:,:])
        plt.axis('off')

plt.show()

# %% [markdown]
# # Use a Residual Block
# The 2-layer plain neural network has acquired an accuracy of 98.2%.
# In this section we will use a three layer neural network, add a shortcut to bypass the first two layers, thus feed the input directly to the second relu layer.

# %% [markdown]
# ## Overfit Small Data
# With small dataset i.e. 1000 images, train two networks independently, the first doesn't use residual block, the second uses.

# %%
input_size = 28 * 28
hidden_size = 50
hidden2_size = 50
num_classes = 10
net_s = ThreeLayerNet(input_size, hidden_size, hidden2_size, num_classes, std=0.005, use_Res=False)

# Train the network
stats_s = net_s.train(X_train_small, y_train_small, X_val, y_val,
            num_iters=2500, batch_size=20,
            learning_rate=5e-4, learning_rate_decay=0.99,
            reg=0.1, verbose=True)

# Predict on the validation set
val_acc = (net_s.predict(X_val) == y_val).mean()
train_acc = (net_s.predict(X_train_small) == y_train_small).mean()
print('Validation accuracy: ', val_acc)
print('Train accuracy: ', train_acc)
# Out:
# iteration 0 / 2500: loss 9.040590 val_acc 0.156300 train_acc 0.174000
# iteration 100 / 2500: loss 6.121730 val_acc 0.392200 train_acc 0.407000
# iteration 200 / 2500: loss 2.171045 val_acc 0.733300 train_acc 0.770000
# iteration 300 / 2500: loss 0.841465 val_acc 0.805200 train_acc 0.862000
# iteration 400 / 2500: loss 0.400468 val_acc 0.840900 train_acc 0.900000
# iteration 500 / 2500: loss 0.290472 val_acc 0.852400 train_acc 0.929000
# iteration 600 / 2500: loss 0.316879 val_acc 0.864100 train_acc 0.942000
# iteration 700 / 2500: loss 0.115297 val_acc 0.861900 train_acc 0.957000
# iteration 800 / 2500: loss 0.168201 val_acc 0.866700 train_acc 0.969000
# iteration 900 / 2500: loss 0.107744 val_acc 0.862600 train_acc 0.970000
# iteration 1000 / 2500: loss 0.166250 val_acc 0.866800 train_acc 0.976000
# iteration 1100 / 2500: loss 0.226361 val_acc 0.869300 train_acc 0.974000
# iteration 1200 / 2500: loss 0.124926 val_acc 0.866700 train_acc 0.981000
# iteration 1300 / 2500: loss 0.206275 val_acc 0.867400 train_acc 0.985000
# iteration 1400 / 2500: loss 0.451959 val_acc 0.868600 train_acc 0.987000
# iteration 1500 / 2500: loss 0.112422 val_acc 0.869500 train_acc 0.988000
# iteration 1600 / 2500: loss 0.138961 val_acc 0.870800 train_acc 0.990000
# iteration 1700 / 2500: loss 0.115455 val_acc 0.871900 train_acc 0.991000
# iteration 1800 / 2500: loss 0.119885 val_acc 0.872700 train_acc 0.992000
# iteration 1900 / 2500: loss 0.233575 val_acc 0.874700 train_acc 0.994000
# iteration 2000 / 2500: loss 0.118747 val_acc 0.872900 train_acc 0.994000
# iteration 2100 / 2500: loss 0.099301 val_acc 0.873100 train_acc 0.994000
# iteration 2200 / 2500: loss 0.099189 val_acc 0.873500 train_acc 0.997000
# iteration 2300 / 2500: loss 0.104151 val_acc 0.872200 train_acc 0.999000
# iteration 2400 / 2500: loss 0.101987 val_acc 0.873400 train_acc 0.998000
# Validation accuracy:  0.8711
# Train accuracy:  0.999

# %%
input_size = 28 * 28
hidden_size = 50
hidden2_size = 50
num_classes = 10
net_s_r = ThreeLayerNet(input_size, hidden_size, hidden2_size, num_classes, std=0.005, use_Res=True)

# Train the network
stats_s_r = net_s_r.train(X_train_small, y_train_small, X_val, y_val,
            num_iters=2500, batch_size=20,
            learning_rate=5e-4, learning_rate_decay=0.99,
            reg=0.1, verbose=True)

# Predict on the validation set
val_acc = (net_s_r.predict(X_val) == y_val).mean()
train_acc = (net_s_r.predict(X_train_small) == y_train_small).mean()
print('Validation accuracy: ', val_acc)
print('Train accuracy: ', train_acc)
# Out:
# iteration 0 / 2500: loss 8.872841 val_acc 0.227400 train_acc 0.256000
# iteration 100 / 2500: loss 0.621782 val_acc 0.870900 train_acc 0.950000
# iteration 200 / 2500: loss 0.123824 val_acc 0.887000 train_acc 0.982000
# iteration 300 / 2500: loss 0.133757 val_acc 0.883800 train_acc 0.990000
# iteration 400 / 2500: loss 0.114618 val_acc 0.889700 train_acc 0.994000
# iteration 500 / 2500: loss 0.108414 val_acc 0.889500 train_acc 0.999000
# iteration 600 / 2500: loss 0.108149 val_acc 0.885800 train_acc 0.999000
# iteration 700 / 2500: loss 0.107766 val_acc 0.885800 train_acc 0.999000
# iteration 800 / 2500: loss 0.107318 val_acc 0.886000 train_acc 1.000000
# iteration 900 / 2500: loss 0.106926 val_acc 0.886900 train_acc 1.000000
# iteration 1000 / 2500: loss 0.106512 val_acc 0.885800 train_acc 1.000000
# iteration 1100 / 2500: loss 0.106096 val_acc 0.886600 train_acc 1.000000
# iteration 1200 / 2500: loss 0.105701 val_acc 0.885800 train_acc 1.000000
# iteration 1300 / 2500: loss 0.105313 val_acc 0.886700 train_acc 1.000000
# iteration 1400 / 2500: loss 0.104926 val_acc 0.886700 train_acc 1.000000
# iteration 1500 / 2500: loss 0.104550 val_acc 0.886700 train_acc 1.000000
# iteration 1600 / 2500: loss 0.104189 val_acc 0.885900 train_acc 1.000000
# iteration 1700 / 2500: loss 0.103837 val_acc 0.886000 train_acc 1.000000
# iteration 1800 / 2500: loss 0.103495 val_acc 0.887200 train_acc 1.000000
# iteration 1900 / 2500: loss 0.103157 val_acc 0.887200 train_acc 1.000000
# iteration 2000 / 2500: loss 0.102829 val_acc 0.887200 train_acc 1.000000
# iteration 2100 / 2500: loss 0.102510 val_acc 0.887200 train_acc 1.000000
# iteration 2200 / 2500: loss 0.102198 val_acc 0.887200 train_acc 1.000000
# iteration 2300 / 2500: loss 0.101899 val_acc 0.886900 train_acc 1.000000
# iteration 2400 / 2500: loss 0.101604 val_acc 0.886900 train_acc 1.000000
# Validation accuracy:  0.8869
# Train accuracy:  1.0

# %%
# Plot the loss function and train / validation accuracies
plt.rcParams['figure.figsize'] = (18.0, 10.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'none'

plt.subplot(2, 1, 1)
plt.plot(stats_s['loss_history'], 'r', label="without residual")
plt.plot(stats_s_r['loss_history'], 'b', label="with residual")
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(stats_s['train_acc_history'], 'r', label="no residual train acc")
plt.plot(stats_s_r['train_acc_history'], 'b', label="with residual train acc")
plt.plot(stats_s['val_acc_history'], 'g', label="no residual validation acc")
plt.plot(stats_s_r['val_acc_history'], 'm', label="with residual validation acc")
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Training: Performance of Residual Block
# Train two networks independently, the first one does not use residual block, the second uses.

# %%
input_size = 28 * 28
hidden_size = 500
hidden2_size = 200
num_classes = 10
net_b = ThreeLayerNet(input_size, hidden_size, hidden2_size, num_classes, std = 0.005, use_Res=False)

# Train the network
stats_b = net_b.train(X_train, y_train, X_val, y_val,
            num_iters=10000, batch_size=100,
            learning_rate=1e-3, learning_rate_decay=0.99,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net_b.predict(X_val) == y_val).mean()
train_acc = (net_b.predict(X_train) == y_train).mean()
print('Validation accuracy: ', val_acc)
print('Train accuracy: ', train_acc)
# Out:
# iteration 0 / 10000: loss 11.983604 val_acc 0.192900 train_acc 0.182100
# iteration 100 / 10000: loss 3.618427 val_acc 0.900400 train_acc 0.890360
# iteration 200 / 10000: loss 3.249347 val_acc 0.920800 train_acc 0.914100
# iteration 300 / 10000: loss 2.821982 val_acc 0.935500 train_acc 0.928440
# iteration 400 / 10000: loss 2.453917 val_acc 0.945300 train_acc 0.936440
# iteration 500 / 10000: loss 2.409638 val_acc 0.947400 train_acc 0.942320
# iteration 600 / 10000: loss 2.246352 val_acc 0.949700 train_acc 0.944520
# iteration 700 / 10000: loss 2.097203 val_acc 0.954400 train_acc 0.948920
# iteration 800 / 10000: loss 1.899041 val_acc 0.954700 train_acc 0.951780
# iteration 900 / 10000: loss 1.702401 val_acc 0.957400 train_acc 0.953960
# iteration 1000 / 10000: loss 1.638054 val_acc 0.959100 train_acc 0.956800
# iteration 1100 / 10000: loss 1.492375 val_acc 0.960100 train_acc 0.958360
# iteration 1200 / 10000: loss 1.395461 val_acc 0.961100 train_acc 0.960080
# iteration 1300 / 10000: loss 1.382126 val_acc 0.962000 train_acc 0.961180
# iteration 1400 / 10000: loss 1.215770 val_acc 0.964300 train_acc 0.962340
# iteration 1500 / 10000: loss 1.061052 val_acc 0.964100 train_acc 0.963560
# iteration 1600 / 10000: loss 1.030811 val_acc 0.964100 train_acc 0.964640
# iteration 1700 / 10000: loss 1.025908 val_acc 0.964500 train_acc 0.965380
# iteration 1800 / 10000: loss 0.993348 val_acc 0.967100 train_acc 0.967160
# iteration 1900 / 10000: loss 0.965644 val_acc 0.965500 train_acc 0.967600
# iteration 2000 / 10000: loss 0.989356 val_acc 0.966500 train_acc 0.967740
# iteration 2100 / 10000: loss 0.863681 val_acc 0.967600 train_acc 0.968720
# iteration 2200 / 10000: loss 0.805147 val_acc 0.968500 train_acc 0.968820
# iteration 2300 / 10000: loss 0.755218 val_acc 0.968600 train_acc 0.969880
# iteration 2400 / 10000: loss 0.767350 val_acc 0.967700 train_acc 0.968840
# iteration 2500 / 10000: loss 0.805392 val_acc 0.970300 train_acc 0.970740
# iteration 2600 / 10000: loss 0.690770 val_acc 0.969500 train_acc 0.969600
# iteration 2700 / 10000: loss 0.800791 val_acc 0.969300 train_acc 0.970600
# iteration 2800 / 10000: loss 0.647301 val_acc 0.970200 train_acc 0.971760
# iteration 2900 / 10000: loss 0.635299 val_acc 0.968500 train_acc 0.972280
# iteration 3000 / 10000: loss 0.626771 val_acc 0.969400 train_acc 0.972260
# iteration 3100 / 10000: loss 0.795565 val_acc 0.971400 train_acc 0.973520
# iteration 3200 / 10000: loss 0.563290 val_acc 0.971700 train_acc 0.973660
# iteration 3300 / 10000: loss 0.567336 val_acc 0.971200 train_acc 0.973620
# iteration 3400 / 10000: loss 0.550719 val_acc 0.971900 train_acc 0.973780
# iteration 3500 / 10000: loss 0.563798 val_acc 0.971600 train_acc 0.973640
# iteration 3600 / 10000: loss 0.525751 val_acc 0.973000 train_acc 0.974560
# iteration 3700 / 10000: loss 0.579332 val_acc 0.971800 train_acc 0.974020
# iteration 3800 / 10000: loss 0.601488 val_acc 0.973500 train_acc 0.974300
# iteration 3900 / 10000: loss 0.520081 val_acc 0.972500 train_acc 0.974900
# iteration 4000 / 10000: loss 0.633963 val_acc 0.969900 train_acc 0.974220
# iteration 4100 / 10000: loss 0.499098 val_acc 0.971600 train_acc 0.975040
# iteration 4200 / 10000: loss 0.530679 val_acc 0.973700 train_acc 0.974700
# iteration 4300 / 10000: loss 0.430906 val_acc 0.972400 train_acc 0.974700
# iteration 4400 / 10000: loss 0.551203 val_acc 0.973200 train_acc 0.975120
# iteration 4500 / 10000: loss 0.539321 val_acc 0.973100 train_acc 0.975860
# iteration 4600 / 10000: loss 0.494139 val_acc 0.972800 train_acc 0.975260
# iteration 4700 / 10000: loss 0.541954 val_acc 0.972600 train_acc 0.976060
# iteration 4800 / 10000: loss 0.498828 val_acc 0.973500 train_acc 0.975840
# iteration 4900 / 10000: loss 0.604876 val_acc 0.973400 train_acc 0.976400
# iteration 5000 / 10000: loss 0.418063 val_acc 0.973500 train_acc 0.976040
# iteration 5100 / 10000: loss 0.511557 val_acc 0.973200 train_acc 0.975920
# iteration 5200 / 10000: loss 0.475096 val_acc 0.973200 train_acc 0.976640
# iteration 5300 / 10000: loss 0.519733 val_acc 0.972500 train_acc 0.976100
# iteration 5400 / 10000: loss 0.438201 val_acc 0.973200 train_acc 0.976480
# iteration 5500 / 10000: loss 0.465633 val_acc 0.973700 train_acc 0.976840
# iteration 5600 / 10000: loss 0.479996 val_acc 0.973800 train_acc 0.976680
# iteration 5700 / 10000: loss 0.435236 val_acc 0.974400 train_acc 0.976980
# iteration 5800 / 10000: loss 0.457783 val_acc 0.973800 train_acc 0.976740
# iteration 5900 / 10000: loss 0.491743 val_acc 0.974500 train_acc 0.977360
# iteration 6000 / 10000: loss 0.463977 val_acc 0.974400 train_acc 0.976940
# iteration 6100 / 10000: loss 0.512283 val_acc 0.973600 train_acc 0.976840
# iteration 6200 / 10000: loss 0.386045 val_acc 0.973900 train_acc 0.976480
# iteration 6300 / 10000: loss 0.545567 val_acc 0.974500 train_acc 0.977520
# iteration 6400 / 10000: loss 0.431491 val_acc 0.973500 train_acc 0.977020
# iteration 6500 / 10000: loss 0.451512 val_acc 0.974900 train_acc 0.977880
# iteration 6600 / 10000: loss 0.460289 val_acc 0.974300 train_acc 0.977500
# iteration 6700 / 10000: loss 0.389423 val_acc 0.975800 train_acc 0.977740
# iteration 6800 / 10000: loss 0.455829 val_acc 0.975700 train_acc 0.977540
# iteration 6900 / 10000: loss 0.512685 val_acc 0.974100 train_acc 0.977140
# iteration 7000 / 10000: loss 0.501527 val_acc 0.974100 train_acc 0.976320
# iteration 7100 / 10000: loss 0.470775 val_acc 0.975300 train_acc 0.977260
# iteration 7200 / 10000: loss 0.394766 val_acc 0.974500 train_acc 0.977060
# iteration 7300 / 10000: loss 0.428690 val_acc 0.975200 train_acc 0.977320
# iteration 7400 / 10000: loss 0.451419 val_acc 0.974700 train_acc 0.977760
# iteration 7500 / 10000: loss 0.377751 val_acc 0.975200 train_acc 0.977700
# iteration 7600 / 10000: loss 0.375816 val_acc 0.975000 train_acc 0.978160
# iteration 7700 / 10000: loss 0.483064 val_acc 0.974700 train_acc 0.977620
# iteration 7800 / 10000: loss 0.438929 val_acc 0.975500 train_acc 0.977900
# iteration 7900 / 10000: loss 0.531838 val_acc 0.974700 train_acc 0.977640
# iteration 8000 / 10000: loss 0.536749 val_acc 0.975000 train_acc 0.977520
# iteration 8100 / 10000: loss 0.432542 val_acc 0.975300 train_acc 0.978060
# iteration 8200 / 10000: loss 0.436476 val_acc 0.975000 train_acc 0.977720
# iteration 8300 / 10000: loss 0.384510 val_acc 0.976300 train_acc 0.978600
# iteration 8400 / 10000: loss 0.456316 val_acc 0.974700 train_acc 0.977920
# iteration 8500 / 10000: loss 0.495133 val_acc 0.976400 train_acc 0.978400
# iteration 8600 / 10000: loss 0.405703 val_acc 0.975300 train_acc 0.978240
# iteration 8700 / 10000: loss 0.390397 val_acc 0.975400 train_acc 0.978580
# iteration 8800 / 10000: loss 0.417943 val_acc 0.975000 train_acc 0.978160
# iteration 8900 / 10000: loss 0.421850 val_acc 0.975400 train_acc 0.978020
# iteration 9000 / 10000: loss 0.452890 val_acc 0.975100 train_acc 0.978640
# iteration 9100 / 10000: loss 0.380240 val_acc 0.975700 train_acc 0.977960
# iteration 9200 / 10000: loss 0.355378 val_acc 0.976100 train_acc 0.978120
# iteration 9300 / 10000: loss 0.417230 val_acc 0.974300 train_acc 0.978680
# iteration 9400 / 10000: loss 0.389646 val_acc 0.974500 train_acc 0.978000
# iteration 9500 / 10000: loss 0.438480 val_acc 0.974900 train_acc 0.977960
# iteration 9600 / 10000: loss 0.387795 val_acc 0.975600 train_acc 0.977960
# iteration 9700 / 10000: loss 0.444302 val_acc 0.974800 train_acc 0.978420
# iteration 9800 / 10000: loss 0.482155 val_acc 0.975300 train_acc 0.978900
# iteration 9900 / 10000: loss 0.558597 val_acc 0.976700 train_acc 0.979360
# Validation accuracy:  0.9754
# Train accuracy:  0.97806

# %% [markdown]
# The second one uses residual block.

# %%
input_size = 28 * 28
hidden_size = 500
hidden2_size = 200
num_classes = 10
net_b_r = ThreeLayerNet(input_size, hidden_size, hidden2_size, num_classes, std=0.005, use_Res=True)

# Train the network
stats_b_r = net_b_r.train(X_train, y_train, X_val, y_val,
            num_iters=10000, batch_size=100,
            learning_rate=1e-3, learning_rate_decay=0.99,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net_b_r.predict(X_val) == y_val).mean()
train_acc = (net_b_r.predict(X_train) == y_train).mean()
print('Validation accuracy: ', val_acc)
print('Train accuracy: ', train_acc)
# Out:
# iteration 0 / 10000: loss 13.240004 val_acc 0.500700 train_acc 0.483440
# iteration 100 / 10000: loss 4.113137 val_acc 0.919200 train_acc 0.912780
# iteration 200 / 10000: loss 3.688032 val_acc 0.943400 train_acc 0.941520
# iteration 300 / 10000: loss 3.504444 val_acc 0.952400 train_acc 0.949540
# iteration 400 / 10000: loss 3.268754 val_acc 0.958800 train_acc 0.960120
# iteration 500 / 10000: loss 3.172097 val_acc 0.958300 train_acc 0.962840
# iteration 600 / 10000: loss 2.855724 val_acc 0.963300 train_acc 0.965300
# iteration 700 / 10000: loss 2.739316 val_acc 0.964400 train_acc 0.968880
# iteration 800 / 10000: loss 2.576663 val_acc 0.966000 train_acc 0.971000
# iteration 900 / 10000: loss 2.481110 val_acc 0.965300 train_acc 0.973120
# iteration 1000 / 10000: loss 2.321768 val_acc 0.966900 train_acc 0.976900
# iteration 1100 / 10000: loss 2.185762 val_acc 0.969200 train_acc 0.978840
# iteration 1200 / 10000: loss 2.169554 val_acc 0.966900 train_acc 0.974940
# iteration 1300 / 10000: loss 2.007929 val_acc 0.967900 train_acc 0.978320
# iteration 1400 / 10000: loss 1.949992 val_acc 0.971800 train_acc 0.980800
# iteration 1500 / 10000: loss 1.827483 val_acc 0.971500 train_acc 0.982560
# iteration 1600 / 10000: loss 1.799405 val_acc 0.968600 train_acc 0.980640
# iteration 1700 / 10000: loss 1.706536 val_acc 0.972200 train_acc 0.984000
# iteration 1800 / 10000: loss 1.654391 val_acc 0.971200 train_acc 0.984460
# iteration 1900 / 10000: loss 1.637235 val_acc 0.972200 train_acc 0.985660
# iteration 2000 / 10000: loss 1.601806 val_acc 0.971200 train_acc 0.984640
# iteration 2100 / 10000: loss 1.571724 val_acc 0.971200 train_acc 0.986960
# iteration 2200 / 10000: loss 1.558366 val_acc 0.973200 train_acc 0.985500
# iteration 2300 / 10000: loss 1.469400 val_acc 0.973800 train_acc 0.987440
# iteration 2400 / 10000: loss 1.431071 val_acc 0.973700 train_acc 0.987240
# iteration 2500 / 10000: loss 1.420035 val_acc 0.970900 train_acc 0.985220
# iteration 2600 / 10000: loss 1.420095 val_acc 0.973100 train_acc 0.987500
# iteration 2700 / 10000: loss 1.444464 val_acc 0.973600 train_acc 0.987880
# iteration 2800 / 10000: loss 1.355339 val_acc 0.973100 train_acc 0.988460
# iteration 2900 / 10000: loss 1.370033 val_acc 0.974000 train_acc 0.989320
# iteration 3000 / 10000: loss 1.333673 val_acc 0.973200 train_acc 0.987840
# iteration 3100 / 10000: loss 1.303544 val_acc 0.973100 train_acc 0.988500
# iteration 3200 / 10000: loss 1.344125 val_acc 0.975800 train_acc 0.990260
# iteration 3300 / 10000: loss 1.328944 val_acc 0.976700 train_acc 0.990180
# iteration 3400 / 10000: loss 1.328792 val_acc 0.976000 train_acc 0.990760
# iteration 3500 / 10000: loss 1.266890 val_acc 0.974500 train_acc 0.989660
# iteration 3600 / 10000: loss 1.268960 val_acc 0.976300 train_acc 0.991500
# iteration 3700 / 10000: loss 1.282949 val_acc 0.976600 train_acc 0.991880
# iteration 3800 / 10000: loss 1.258047 val_acc 0.976600 train_acc 0.991240
# iteration 3900 / 10000: loss 1.246561 val_acc 0.976000 train_acc 0.991700
# iteration 4000 / 10000: loss 1.237697 val_acc 0.975900 train_acc 0.991540
# iteration 4100 / 10000: loss 1.232635 val_acc 0.977700 train_acc 0.992360
# iteration 4200 / 10000: loss 1.259772 val_acc 0.977700 train_acc 0.993860
# iteration 4300 / 10000: loss 1.310645 val_acc 0.976300 train_acc 0.991180
# iteration 4400 / 10000: loss 1.238165 val_acc 0.978500 train_acc 0.993300
# iteration 4500 / 10000: loss 1.243434 val_acc 0.976100 train_acc 0.992740
# iteration 4600 / 10000: loss 1.240741 val_acc 0.975300 train_acc 0.993160
# iteration 4700 / 10000: loss 1.228930 val_acc 0.977900 train_acc 0.993800
# iteration 4800 / 10000: loss 1.258009 val_acc 0.977300 train_acc 0.993680
# iteration 4900 / 10000: loss 1.278479 val_acc 0.973500 train_acc 0.992020
# iteration 5000 / 10000: loss 1.250037 val_acc 0.975000 train_acc 0.992900
# iteration 5100 / 10000: loss 1.211890 val_acc 0.978300 train_acc 0.993940
# iteration 5200 / 10000: loss 1.235517 val_acc 0.977200 train_acc 0.993480
# iteration 5300 / 10000: loss 1.202669 val_acc 0.975500 train_acc 0.992300
# iteration 5400 / 10000: loss 1.235211 val_acc 0.976900 train_acc 0.993200
# iteration 5500 / 10000: loss 1.207385 val_acc 0.977300 train_acc 0.993820
# iteration 5600 / 10000: loss 1.216226 val_acc 0.975400 train_acc 0.993680
# iteration 5700 / 10000: loss 1.216368 val_acc 0.978300 train_acc 0.995320
# iteration 5800 / 10000: loss 1.225458 val_acc 0.975000 train_acc 0.993480
# iteration 5900 / 10000: loss 1.218048 val_acc 0.977400 train_acc 0.994700
# iteration 6000 / 10000: loss 1.216346 val_acc 0.978000 train_acc 0.994740
# iteration 6100 / 10000: loss 1.204944 val_acc 0.978800 train_acc 0.995620
# iteration 6200 / 10000: loss 1.201383 val_acc 0.977200 train_acc 0.995000
# iteration 6300 / 10000: loss 1.204949 val_acc 0.979400 train_acc 0.995220
# iteration 6400 / 10000: loss 1.236058 val_acc 0.977300 train_acc 0.994340
# iteration 6500 / 10000: loss 1.211716 val_acc 0.979100 train_acc 0.995080
# iteration 6600 / 10000: loss 1.214715 val_acc 0.978200 train_acc 0.995880
# iteration 6700 / 10000: loss 1.208335 val_acc 0.978700 train_acc 0.996260
# iteration 6800 / 10000: loss 1.222251 val_acc 0.978500 train_acc 0.995660
# iteration 6900 / 10000: loss 1.246076 val_acc 0.979700 train_acc 0.996660
# iteration 7000 / 10000: loss 1.215254 val_acc 0.977300 train_acc 0.995520
# iteration 7100 / 10000: loss 1.226667 val_acc 0.978800 train_acc 0.996300
# iteration 7200 / 10000: loss 1.233135 val_acc 0.977600 train_acc 0.995500
# iteration 7300 / 10000: loss 1.240755 val_acc 0.976100 train_acc 0.995540
# iteration 7400 / 10000: loss 1.220906 val_acc 0.977100 train_acc 0.996180
# iteration 7500 / 10000: loss 1.242133 val_acc 0.977700 train_acc 0.996060
# iteration 7600 / 10000: loss 1.230667 val_acc 0.979200 train_acc 0.995960
# iteration 7700 / 10000: loss 1.220068 val_acc 0.977900 train_acc 0.995980
# iteration 7800 / 10000: loss 1.232001 val_acc 0.978300 train_acc 0.996100
# iteration 7900 / 10000: loss 1.235961 val_acc 0.978800 train_acc 0.995900
# iteration 8000 / 10000: loss 1.243630 val_acc 0.980900 train_acc 0.996400
# iteration 8100 / 10000: loss 1.248413 val_acc 0.980300 train_acc 0.996760
# iteration 8200 / 10000: loss 1.226941 val_acc 0.979700 train_acc 0.996900
# iteration 8300 / 10000: loss 1.239650 val_acc 0.978900 train_acc 0.997220
# iteration 8400 / 10000: loss 1.240955 val_acc 0.979800 train_acc 0.996940
# iteration 8500 / 10000: loss 1.232920 val_acc 0.979700 train_acc 0.996600
# iteration 8600 / 10000: loss 1.261067 val_acc 0.979400 train_acc 0.996600
# iteration 8700 / 10000: loss 1.237985 val_acc 0.979000 train_acc 0.996600
# iteration 8800 / 10000: loss 1.235450 val_acc 0.980000 train_acc 0.997260
# iteration 8900 / 10000: loss 1.252205 val_acc 0.978000 train_acc 0.996560
# iteration 9000 / 10000: loss 1.283446 val_acc 0.980000 train_acc 0.996680
# iteration 9100 / 10000: loss 1.239404 val_acc 0.979400 train_acc 0.997100
# iteration 9200 / 10000: loss 1.239794 val_acc 0.979100 train_acc 0.997220
# iteration 9300 / 10000: loss 1.257705 val_acc 0.979600 train_acc 0.997300
# iteration 9400 / 10000: loss 1.252592 val_acc 0.979700 train_acc 0.997460
# iteration 9500 / 10000: loss 1.254289 val_acc 0.980500 train_acc 0.997740
# iteration 9600 / 10000: loss 1.274933 val_acc 0.979200 train_acc 0.997160
# iteration 9700 / 10000: loss 1.284028 val_acc 0.980100 train_acc 0.997380
# iteration 9800 / 10000: loss 1.274337 val_acc 0.980100 train_acc 0.997320
# iteration 9900 / 10000: loss 1.245961 val_acc 0.980000 train_acc 0.997480
# Validation accuracy:  0.9783
# Train accuracy:  0.99758

# %%
# Plot the loss function and train / validation accuracies
plt.rcParams['figure.figsize'] = (18.0, 10.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'none'

plt.subplot(3, 1, 1)
plt.plot(stats_b['loss_history'], 'r', label="without residual")
plt.plot(stats_b_r['loss_history'], 'b', label="with residual")
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(stats_b['train_acc_history'], 'r', label="no residual train acc")
plt.plot(stats_b_r['train_acc_history'], 'b', label="with residual train acc")
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(stats_b['val_acc_history'], 'g', label="no residual validation acc")
plt.plot(stats_b_r['val_acc_history'], 'm', label="with residual validation acc")
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# The model with residual block performs slightly better than the one doesn't.

# %%
test_acc = (net_b.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
test_acc_r = (net_b_r.predict(X_test) == y_test).mean()
print('Test accuracy with residual: ', test_acc_r)
# Out:
# Test accuracy:  0.9724
# Test accuracy with residual:  0.9786

# %% [markdown]
# # Acknowledgment
# Some of the code and structure is copied from Stanford course [CS231n](https://cs231n.github.io) assignments. Lectured by Fei-Fei Li, Andrej Karpathy, Justion Johnson and Serena Yeung

# %% [markdown]
# # Source code

# %% [markdown]
# On Github: https://github.com/msfanggao/mnist
